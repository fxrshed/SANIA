# %%
# !which python 
# !whoami 
# !hostname
# !pwd
# Out:
# /home/farshed.abdukhakimov/miniconda3/envs/main/bin/python
# farshed.abdukhakimov
# srv-01
# /home/farshed.abdukhakimov/projects/SANIA

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import urllib.request
from collections import defaultdict

import numpy as np
import scipy

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader, SubsetRandomSampler, RandomSampler
import torch.optim as optim

import torchvision
import torchvision.models as models
from torchvision.transforms import v2

from sklearn.datasets import load_svmlight_file

import matplotlib.pyplot as plt

from experiments import utils

from SANIA import SANIA_AdagradSQR, SANIA_AdamSQR

from dotenv import load_dotenv
load_dotenv()

torch.set_default_dtype(torch.float64)
torch.set_num_threads(2)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
device = torch.device('cpu')
device
# Out:
# device(type='cpu')

# %%
torch.random.manual_seed(0)
np.random.seed(0)

dataset_name = "aloi.scale"
train_data, train_target, test_data, test_target = utils.get_libsvm(name=dataset_name, test_split=0.2)

scale = 4    
scaling_vec = utils.generate_scaling_vec(size=train_data.shape[1], scale=scale)
if scipy.sparse.issparse(train_data):
    scaled_train_data = train_data.multiply(scaling_vec).tocsr()
    scaled_test_data = test_data.multiply(scaling_vec).tocsr()
else:
    scaled_train_data = scaling_vec * train_data
    scaled_test_data = scaling_vec * test_data

batch_size = 512

train_data = torch.tensor(train_data.toarray())
scaled_train_data = torch.tensor(scaled_train_data.toarray())
train_target = torch.tensor(train_target, dtype=torch.long) 

test_data = torch.tensor(test_data.toarray())
scaled_test_data = torch.tensor(scaled_test_data.toarray())
test_target = torch.tensor(test_target, dtype=torch.long) 

in_features, n_classes = train_data.shape[1], len(np.unique(test_target))

train_dataloader = DataLoader(TensorDataset(train_data, train_target), 
                              batch_size=batch_size, 
                              shuffle=False)

scaled_train_dataloader = DataLoader(TensorDataset(scaled_train_data, train_target), 
                              batch_size=batch_size, 
                              shuffle=False)

test_dataloader = DataLoader(TensorDataset(test_data, test_target), 
                             batch_size=len(test_data), 
                             shuffle=False)

scaled_test_dataloader = DataLoader(TensorDataset(scaled_test_data, test_target), 
                             batch_size=len(test_data), 
                             shuffle=False)


print(f"{train_data.shape=}")
print(f"{test_data.shape=}")
print("Sparsity: ", 1 - (train_data.count_nonzero() / (train_data.shape[0] * train_data.shape[1])))
# Out:
# Test data for `aloi.scale` is not found. Splitting train into 80.0% train and 20.0% test.
# train_data.shape=torch.Size([86400, 128])
# test_data.shape=torch.Size([21600, 128])
# Sparsity:  tensor(0.7602)

# %%
def plotter(histories, labels, colors=None, linestyles=None, 
            linewidths=None, markers=None, prefix="val", suptitle=None, 
            threshold=1e-10, max_iters=None, tight_layout=True, filename=None):
    
    fig, ax = plt.subplots(1, 2, figsize=(10, 4))
    if suptitle is not None:
        fig.suptitle(suptitle, fontsize=16)
        
    if colors is None:
        colors = list(plt.cm.colors.XKCD_COLORS.keys())
        np.random.shuffle(colors)
        colors = list(plt.cm.colors.BASE_COLORS) + colors
        
    if linestyles is None:
        linestyles = ["-" for x in histories]
    
    if linewidths is None:
        linewidths = [1.5 for x in histories]
        
    if markers is None:
        markers = [" " for x in histories]
        
    
    for history, label, c, ls, lw, m in zip(histories, labels, colors, linestyles, linewidths, markers):
        loss = history["test/loss"]
        acc = history["test/acc"]
        
        markevery = [x + np.random.randint(0, 3) for x in range(0, len(loss), len(loss) // 10)]
        
        ax[0].semilogy(loss, linestyle=ls, linewidth=lw, color=c, markevery=markevery, marker=m)
        ax[1].plot(acc, linestyle=ls, linewidth=lw, color=c, label=label, markevery=markevery, marker=m)

    ax[0].set_ylabel(r"$f(w_i)$")
    ax[1].set_ylabel("Accuracy")
        
    # ax[1].set_ylim(bottom=0.75)
    
    ax[0].set_xlabel("Epochs")
    ax[1].set_xlabel("Epochs")

    fig.legend()
    ax[0].grid()
    ax[1].grid()
    
    if tight_layout:
        fig.tight_layout()
        
    if filename is not None:
        fig.savefig(filename)
    else:
        fig.show()

# %%
def eval_model(model, criterion, test_loader, test_hist) -> None: 
    test_epoch_loss = 0.0
    total = 0
    correct = 0
    for i, (batch_data, batch_target) in enumerate(test_loader):
        batch_data = batch_data.to(device)
        batch_target = batch_target.to(device)
        
        outputs = model(batch_data)
        loss = criterion(outputs, batch_target)
        test_epoch_loss += loss.item() * batch_data.size(0)
        
        _, predicted = torch.max(outputs.data, 1)
        total += batch_target.size(0)
        batch_correct = (predicted == batch_target).sum().item()
        batch_accuracy = batch_correct / batch_target.size(0)
        correct += batch_correct
        
        test_hist["batch_loss"].append(loss.item())
        test_hist["batch_accuracy"].append(batch_accuracy)

    test_hist["epoch_loss"].append(test_epoch_loss / len(test_loader.sampler))
    test_hist["epoch_accuracy"].append(correct / total)

# %%
def train_loop(opt: optim.Optimizer, 
               train_loader: DataLoader, 
               test_loader: DataLoader, 
               epochs: int, 
               seed: int = 0, 
               **optimizer_kwargs):

    torch.manual_seed(0)
    
    model = nn.Linear(in_features=in_features, out_features=n_classes, device=device)    
    optimizer = opt(model.parameters(), **optimizer_kwargs)
    criterion = nn.CrossEntropyLoss()
    
    history = defaultdict(list)
    
    torch.manual_seed(seed)
    
    for epoch in range(epochs):
        
        model.eval()
        with torch.inference_mode():
            outputs = model(test_data)
            test_loss = criterion(outputs, test_target)
            test_preds = torch.argmax(outputs, dim=1) 
            test_acc = (test_preds == test_target).float().mean()  
            history["test/loss"].append(test_loss)
            history["test/acc"].append(test_acc)
            
            print(f"{epoch=}, {test_loss=}, {test_acc=}")

        
        running_loss = 0.0
        model.train()
        for i, (batch_data, batch_target) in enumerate(train_loader): 
            
            batch_data = batch_data.to(device)
            batch_target = batch_target.to(device)
            
            optimizer.zero_grad()

            outputs = model(batch_data)
            def closure():
                return criterion(outputs, batch_target)
            loss = closure()
            running_loss += loss.item()

            loss.backward()
            optimizer.step(closure=closure)
            
            history["train/batch/loss"].append(loss.item())
            
        train_loss = running_loss / len(train_loader)
        history["train/epoch/loss"].append(train_loss)


    return history

# %%
n_epochs = 50

# %%
hist_sgd = train_loop(opt=optim.SGD,
                train_loader=train_dataloader,
                test_loader=test_dataloader, 
                epochs=n_epochs,
                lr=0.1)

hist_sania_adam = train_loop(opt=SANIA_AdamSQR,
                train_loader=train_dataloader,
                test_loader=test_dataloader, 
                epochs=n_epochs)

hist_sania_adagrad = train_loop(opt=SANIA_AdagradSQR,
                train_loader=train_dataloader,
                test_loader=test_dataloader, 
                epochs=n_epochs)

histories = [hist_sgd, hist_sania_adam, hist_sania_adagrad]
labels = ["SGD", "SANIA Adam", "SANIA Adagrad"]
# Out:
# epoch=0, test_loss=tensor(6.9145), test_acc=tensor(0.0001, dtype=torch.float32)
# epoch=1, test_loss=tensor(6.8867), test_acc=tensor(0.0012, dtype=torch.float32)
# epoch=2, test_loss=tensor(6.8592), test_acc=tensor(0.0033, dtype=torch.float32)
# epoch=3, test_loss=tensor(6.8321), test_acc=tensor(0.0067, dtype=torch.float32)
# epoch=4, test_loss=tensor(6.8054), test_acc=tensor(0.0118, dtype=torch.float32)
# epoch=5, test_loss=tensor(6.7791), test_acc=tensor(0.0167, dtype=torch.float32)
# epoch=6, test_loss=tensor(6.7531), test_acc=tensor(0.0224, dtype=torch.float32)
# epoch=7, test_loss=tensor(6.7276), test_acc=tensor(0.0309, dtype=torch.float32)
# epoch=8, test_loss=tensor(6.7023), test_acc=tensor(0.0415, dtype=torch.float32)
# epoch=9, test_loss=tensor(6.6774), test_acc=tensor(0.0527, dtype=torch.float32)
# epoch=10, test_loss=tensor(6.6526), test_acc=tensor(0.0641, dtype=torch.float32)
# epoch=11, test_loss=tensor(6.6282), test_acc=tensor(0.0775, dtype=torch.float32)
# epoch=12, test_loss=tensor(6.6039), test_acc=tensor(0.0947, dtype=torch.float32)
# epoch=13, test_loss=tensor(6.5799), test_acc=tensor(0.1090, dtype=torch.float32)
# epoch=14, test_loss=tensor(6.5560), test_acc=tensor(0.1221, dtype=torch.float32)
# epoch=15, test_loss=tensor(6.5324), test_acc=tensor(0.1342, dtype=torch.float32)
# epoch=16, test_loss=tensor(6.5090), test_acc=tensor(0.1460, dtype=torch.float32)
# epoch=17, test_loss=tensor(6.4857), test_acc=tensor(0.1574, dtype=torch.float32)
# epoch=18, test_loss=tensor(6.4626), test_acc=tensor(0.1680, dtype=torch.float32)
# epoch=19, test_loss=tensor(6.4398), test_acc=tensor(0.1788, dtype=torch.float32)
# epoch=20, test_loss=tensor(6.4171), test_acc=tensor(0.1876, dtype=torch.float32)
# epoch=21, test_loss=tensor(6.3945), test_acc=tensor(0.1973, dtype=torch.float32)
# epoch=22, test_loss=tensor(6.3722), test_acc=tensor(0.2067, dtype=torch.float32)
# epoch=23, test_loss=tensor(6.3500), test_acc=tensor(0.2149, dtype=torch.float32)
# epoch=24, test_loss=tensor(6.3280), test_acc=tensor(0.2218, dtype=torch.float32)
# epoch=25, test_loss=tensor(6.3061), test_acc=tensor(0.2290, dtype=torch.float32)
# epoch=26, test_loss=tensor(6.2844), test_acc=tensor(0.2357, dtype=torch.float32)
# epoch=27, test_loss=tensor(6.2628), test_acc=tensor(0.2424, dtype=torch.float32)
# epoch=28, test_loss=tensor(6.2415), test_acc=tensor(0.2492, dtype=torch.float32)
# epoch=29, test_loss=tensor(6.2202), test_acc=tensor(0.2540, dtype=torch.float32)
# epoch=30, test_loss=tensor(6.1991), test_acc=tensor(0.2591, dtype=torch.float32)
# epoch=31, test_loss=tensor(6.1782), test_acc=tensor(0.2645, dtype=torch.float32)
# epoch=32, test_loss=tensor(6.1574), test_acc=tensor(0.2688, dtype=torch.float32)
# epoch=33, test_loss=tensor(6.1368), test_acc=tensor(0.2731, dtype=torch.float32)
# epoch=34, test_loss=tensor(6.1163), test_acc=tensor(0.2785, dtype=torch.float32)
# epoch=35, test_loss=tensor(6.0960), test_acc=tensor(0.2831, dtype=torch.float32)
# epoch=36, test_loss=tensor(6.0758), test_acc=tensor(0.2870, dtype=torch.float32)
# epoch=37, test_loss=tensor(6.0557), test_acc=tensor(0.2919, dtype=torch.float32)
# epoch=38, test_loss=tensor(6.0358), test_acc=tensor(0.2952, dtype=torch.float32)
# epoch=39, test_loss=tensor(6.0160), test_acc=tensor(0.2980, dtype=torch.float32)
# epoch=40, test_loss=tensor(5.9964), test_acc=tensor(0.3019, dtype=torch.float32)
# epoch=41, test_loss=tensor(5.9769), test_acc=tensor(0.3052, dtype=torch.float32)
# epoch=42, test_loss=tensor(5.9575), test_acc=tensor(0.3088, dtype=torch.float32)
# epoch=43, test_loss=tensor(5.9383), test_acc=tensor(0.3114, dtype=torch.float32)
# epoch=44, test_loss=tensor(5.9192), test_acc=tensor(0.3146, dtype=torch.float32)
# epoch=45, test_loss=tensor(5.9003), test_acc=tensor(0.3179, dtype=torch.float32)
# epoch=46, test_loss=tensor(5.8814), test_acc=tensor(0.3210, dtype=torch.float32)
# epoch=47, test_loss=tensor(5.8627), test_acc=tensor(0.3238, dtype=torch.float32)
# epoch=48, test_loss=tensor(5.8442), test_acc=tensor(0.3268, dtype=torch.float32)
# epoch=49, test_loss=tensor(5.8257), test_acc=tensor(0.3291, dtype=torch.float32)
# epoch=0, test_loss=tensor(6.9145), test_acc=tensor(0.0001, dtype=torch.float32)
# epoch=1, test_loss=tensor(5.0505), test_acc=tensor(0.3191, dtype=torch.float32)
# epoch=2, test_loss=tensor(4.0620), test_acc=tensor(0.4925, dtype=torch.float32)
# epoch=3, test_loss=tensor(3.4541), test_acc=tensor(0.5798, dtype=torch.float32)
# epoch=4, test_loss=tensor(3.0383), test_acc=tensor(0.6279, dtype=torch.float32)
# epoch=5, test_loss=tensor(2.7344), test_acc=tensor(0.6636, dtype=torch.float32)
# epoch=6, test_loss=tensor(2.5020), test_acc=tensor(0.6893, dtype=torch.float32)
# epoch=7, test_loss=tensor(2.3180), test_acc=tensor(0.7073, dtype=torch.float32)
# epoch=8, test_loss=tensor(2.1686), test_acc=tensor(0.7236, dtype=torch.float32)
# epoch=9, test_loss=tensor(2.0445), test_acc=tensor(0.7344, dtype=torch.float32)
# epoch=10, test_loss=tensor(1.9396), test_acc=tensor(0.7434, dtype=torch.float32)
# epoch=11, test_loss=tensor(1.8497), test_acc=tensor(0.7531, dtype=torch.float32)
# epoch=12, test_loss=tensor(1.7717), test_acc=tensor(0.7618, dtype=torch.float32)
# epoch=13, test_loss=tensor(1.7033), test_acc=tensor(0.7691, dtype=torch.float32)
# epoch=14, test_loss=tensor(1.6426), test_acc=tensor(0.7752, dtype=torch.float32)
# epoch=15, test_loss=tensor(1.5885), test_acc=tensor(0.7807, dtype=torch.float32)
# epoch=16, test_loss=tensor(1.5398), test_acc=tensor(0.7847, dtype=torch.float32)
# epoch=17, test_loss=tensor(1.4958), test_acc=tensor(0.7884, dtype=torch.float32)
# epoch=18, test_loss=tensor(1.4557), test_acc=tensor(0.7928, dtype=torch.float32)
# epoch=19, test_loss=tensor(1.4190), test_acc=tensor(0.7967, dtype=torch.float32)
# epoch=20, test_loss=tensor(1.3853), test_acc=tensor(0.7991, dtype=torch.float32)
# epoch=21, test_loss=tensor(1.3542), test_acc=tensor(0.8018, dtype=torch.float32)
# epoch=22, test_loss=tensor(1.3254), test_acc=tensor(0.8049, dtype=torch.float32)
# epoch=23, test_loss=tensor(1.2986), test_acc=tensor(0.8075, dtype=torch.float32)
# epoch=24, test_loss=tensor(1.2736), test_acc=tensor(0.8098, dtype=torch.float32)
# epoch=25, test_loss=tensor(1.2502), test_acc=tensor(0.8120, dtype=torch.float32)
# epoch=26, test_loss=tensor(1.2283), test_acc=tensor(0.8142, dtype=torch.float32)
# epoch=27, test_loss=tensor(1.2076), test_acc=tensor(0.8166, dtype=torch.float32)
# epoch=28, test_loss=tensor(1.1882), test_acc=tensor(0.8186, dtype=torch.float32)
# epoch=29, test_loss=tensor(1.1698), test_acc=tensor(0.8204, dtype=torch.float32)
# epoch=30, test_loss=tensor(1.1524), test_acc=tensor(0.8225, dtype=torch.float32)
# epoch=31, test_loss=tensor(1.1359), test_acc=tensor(0.8241, dtype=torch.float32)
# epoch=32, test_loss=tensor(1.1203), test_acc=tensor(0.8259, dtype=torch.float32)
# epoch=33, test_loss=tensor(1.1054), test_acc=tensor(0.8277, dtype=torch.float32)
# epoch=34, test_loss=tensor(1.0912), test_acc=tensor(0.8290, dtype=torch.float32)
# epoch=35, test_loss=tensor(1.0776), test_acc=tensor(0.8306, dtype=torch.float32)
# epoch=36, test_loss=tensor(1.0646), test_acc=tensor(0.8318, dtype=torch.float32)
# epoch=37, test_loss=tensor(1.0522), test_acc=tensor(0.8330, dtype=torch.float32)
# epoch=38, test_loss=tensor(1.0403), test_acc=tensor(0.8342, dtype=torch.float32)
# epoch=39, test_loss=tensor(1.0289), test_acc=tensor(0.8353, dtype=torch.float32)
# epoch=40, test_loss=tensor(1.0180), test_acc=tensor(0.8363, dtype=torch.float32)
# epoch=41, test_loss=tensor(1.0074), test_acc=tensor(0.8373, dtype=torch.float32)
# epoch=42, test_loss=tensor(0.9973), test_acc=tensor(0.8383, dtype=torch.float32)
# epoch=43, test_loss=tensor(0.9875), test_acc=tensor(0.8396, dtype=torch.float32)
# epoch=44, test_loss=tensor(0.9781), test_acc=tensor(0.8405, dtype=torch.float32)
# epoch=45, test_loss=tensor(0.9690), test_acc=tensor(0.8415, dtype=torch.float32)
# epoch=46, test_loss=tensor(0.9602), test_acc=tensor(0.8422, dtype=torch.float32)
# epoch=47, test_loss=tensor(0.9517), test_acc=tensor(0.8431, dtype=torch.float32)
# epoch=48, test_loss=tensor(0.9435), test_acc=tensor(0.8438, dtype=torch.float32)
# epoch=49, test_loss=tensor(0.9356), test_acc=tensor(0.8446, dtype=torch.float32)
# epoch=0, test_loss=tensor(6.9145), test_acc=tensor(0.0001, dtype=torch.float32)
# epoch=1, test_loss=tensor(5.0505), test_acc=tensor(0.3191, dtype=torch.float32)
# epoch=2, test_loss=tensor(4.0620), test_acc=tensor(0.4925, dtype=torch.float32)
# epoch=3, test_loss=tensor(3.4541), test_acc=tensor(0.5798, dtype=torch.float32)
# epoch=4, test_loss=tensor(3.0383), test_acc=tensor(0.6279, dtype=torch.float32)
# epoch=5, test_loss=tensor(2.7344), test_acc=tensor(0.6636, dtype=torch.float32)
# epoch=6, test_loss=tensor(2.5020), test_acc=tensor(0.6893, dtype=torch.float32)
# epoch=7, test_loss=tensor(2.3180), test_acc=tensor(0.7073, dtype=torch.float32)
# epoch=8, test_loss=tensor(2.1686), test_acc=tensor(0.7236, dtype=torch.float32)
# epoch=9, test_loss=tensor(2.0445), test_acc=tensor(0.7344, dtype=torch.float32)
# epoch=10, test_loss=tensor(1.9396), test_acc=tensor(0.7434, dtype=torch.float32)
# epoch=11, test_loss=tensor(1.8497), test_acc=tensor(0.7531, dtype=torch.float32)
# epoch=12, test_loss=tensor(1.7717), test_acc=tensor(0.7618, dtype=torch.float32)
# epoch=13, test_loss=tensor(1.7033), test_acc=tensor(0.7691, dtype=torch.float32)
# epoch=14, test_loss=tensor(1.6426), test_acc=tensor(0.7752, dtype=torch.float32)
# epoch=15, test_loss=tensor(1.5885), test_acc=tensor(0.7807, dtype=torch.float32)
# epoch=16, test_loss=tensor(1.5398), test_acc=tensor(0.7847, dtype=torch.float32)
# epoch=17, test_loss=tensor(1.4958), test_acc=tensor(0.7884, dtype=torch.float32)
# epoch=18, test_loss=tensor(1.4557), test_acc=tensor(0.7928, dtype=torch.float32)
# epoch=19, test_loss=tensor(1.4190), test_acc=tensor(0.7967, dtype=torch.float32)
# epoch=20, test_loss=tensor(1.3853), test_acc=tensor(0.7991, dtype=torch.float32)
# epoch=21, test_loss=tensor(1.3542), test_acc=tensor(0.8018, dtype=torch.float32)
# epoch=22, test_loss=tensor(1.3254), test_acc=tensor(0.8049, dtype=torch.float32)
# epoch=23, test_loss=tensor(1.2986), test_acc=tensor(0.8075, dtype=torch.float32)
# epoch=24, test_loss=tensor(1.2736), test_acc=tensor(0.8098, dtype=torch.float32)
# epoch=25, test_loss=tensor(1.2502), test_acc=tensor(0.8120, dtype=torch.float32)
# epoch=26, test_loss=tensor(1.2283), test_acc=tensor(0.8142, dtype=torch.float32)
# epoch=27, test_loss=tensor(1.2076), test_acc=tensor(0.8166, dtype=torch.float32)
# epoch=28, test_loss=tensor(1.1882), test_acc=tensor(0.8186, dtype=torch.float32)
# epoch=29, test_loss=tensor(1.1698), test_acc=tensor(0.8204, dtype=torch.float32)
# epoch=30, test_loss=tensor(1.1524), test_acc=tensor(0.8225, dtype=torch.float32)
# epoch=31, test_loss=tensor(1.1359), test_acc=tensor(0.8241, dtype=torch.float32)
# epoch=32, test_loss=tensor(1.1203), test_acc=tensor(0.8259, dtype=torch.float32)
# epoch=33, test_loss=tensor(1.1054), test_acc=tensor(0.8277, dtype=torch.float32)
# epoch=34, test_loss=tensor(1.0912), test_acc=tensor(0.8290, dtype=torch.float32)
# epoch=35, test_loss=tensor(1.0776), test_acc=tensor(0.8306, dtype=torch.float32)
# epoch=36, test_loss=tensor(1.0646), test_acc=tensor(0.8318, dtype=torch.float32)
# epoch=37, test_loss=tensor(1.0522), test_acc=tensor(0.8330, dtype=torch.float32)
# epoch=38, test_loss=tensor(1.0403), test_acc=tensor(0.8342, dtype=torch.float32)
# epoch=39, test_loss=tensor(1.0289), test_acc=tensor(0.8353, dtype=torch.float32)
# epoch=40, test_loss=tensor(1.0180), test_acc=tensor(0.8363, dtype=torch.float32)
# epoch=41, test_loss=tensor(1.0074), test_acc=tensor(0.8373, dtype=torch.float32)
# epoch=42, test_loss=tensor(0.9973), test_acc=tensor(0.8383, dtype=torch.float32)
# epoch=43, test_loss=tensor(0.9875), test_acc=tensor(0.8396, dtype=torch.float32)
# epoch=44, test_loss=tensor(0.9781), test_acc=tensor(0.8405, dtype=torch.float32)
# epoch=45, test_loss=tensor(0.9690), test_acc=tensor(0.8415, dtype=torch.float32)
# epoch=46, test_loss=tensor(0.9602), test_acc=tensor(0.8422, dtype=torch.float32)
# epoch=47, test_loss=tensor(0.9517), test_acc=tensor(0.8431, dtype=torch.float32)
# epoch=48, test_loss=tensor(0.9435), test_acc=tensor(0.8438, dtype=torch.float32)
# epoch=49, test_loss=tensor(0.9356), test_acc=tensor(0.8446, dtype=torch.float32)

# %%
plotter(histories=histories, 
    labels=labels,
    colors=["black", "red", "blue", "purple", "teal", "lime"],
    linestyles=["-", "--", ":", "--", "-", "--"],
    prefix="test",
    suptitle=f"{dataset_name}",
    )

# %%
hist = train_loop(opt=SANIA_AdamSQR,
                train_loader=train_dataloader,
                test_loader=test_dataloader, 
                epochs=n_epochs,
                eps=1e-10)

scaled_hist = train_loop(opt=SANIA_AdamSQR,
                train_loader=scaled_train_dataloader,
                test_loader=scaled_test_dataloader, 
                epochs=n_epochs,
                eps=1e-10)

histories = [hist, scaled_hist]
labels = ["SANIA Adam", "SANIA Adam scaled"]

# %%
plotter(histories=histories, 
    labels=labels,
    colors=["black", "red", "blue", "purple", "teal", "lime"],
    linestyles=["-", "--", "-", "--", "-", "--"],
    prefix="test",
    suptitle=f"{dataset_name}",
    )

# %%
n_epochs = 50

batch_size = 16
seed = 0
lmd = 0.0

# for seed in range(5):

histories = []
labels = []

optimizer = SANIA_AdamSQR
eps = 0.0
hist = train_loop(seed=seed, train_dataset=train_dataset, test_dataset=test_dataset, 
                batch_size=batch_size, n_epochs=n_epochs, optimizer=optimizer,
                lmd=lmd, eps=eps)
histories.append(hist)
labels.append(f"{optimizer.__name__}, {eps=}")

optimizer = SANIA_AdamSQR
eps = 0.0
hist = train_loop(seed=seed, train_dataset=scaled_train_dataset, test_dataset=scaled_test_dataset, 
                batch_size=batch_size, n_epochs=n_epochs, optimizer=optimizer, 
                lmd=lmd, eps=eps)
histories.append(hist)
labels.append(f"{optimizer.__name__} (scaled), {eps=}")

plotter(histories=histories, 
    labels=labels,
    colors=["black", "red", "blue", "purple", "teal", "lime"],
    linestyles=["-", "--", "-", "--", "-", "--"],
    prefix="test",
    suptitle=f"Logistic Regression, {dataset_name}, seed={seed}",
    )

# %%
seed = 0
n_epochs = 100

histories = []
labels = []

for lr in  [0.1, 1.0]:

    optimizer = Adam
    hist = train_loop(seed=seed, train_dataset=train_dataset, test_dataset=test_dataset, 
                    batch_size=batch_size, n_epochs=n_epochs, optimizer=optimizer,
                    lmd=lmd, lr=lr)
    histories.append(hist)
    labels.append(f"{optimizer.__name__}, {lr=}")

    hist = train_loop(seed=seed, train_dataset=scaled_train_dataset, test_dataset=scaled_test_dataset, 
                    batch_size=batch_size, n_epochs=n_epochs, optimizer=optimizer, 
                    lmd=lmd, lr=lr)
    histories.append(hist)
    labels.append(f"{optimizer.__name__} (scaled), {lr=}")

plotter(histories=histories, 
    labels=labels,
    colors=["black", "red", "blue", "purple", "teal", "lime"],
    linestyles=["-", "--", "-", "--", "-", "--"],
    prefix="test",
    suptitle=f"Logistic Regression, {dataset_name}, seed={seed}",
    )

# %%
def rademacher_old(weights):
    return torch.round(torch.rand_like(weights)) * 2 - 1

def diag_estimate_old(weights, grad, iters):
    Ds = []
    for j in range(iters):
        z = rademacher_old(weights)
        with torch.no_grad():
            hvp = torch.autograd.grad(grad, weights, grad_outputs=z, retain_graph=True)[0]
        Ds.append((hvp*z))

    return torch.mean(torch.stack(Ds), 0)

def ttv(tuple_in):
    return torch.cat([t.view(-1) for t in tuple_in])

def flat_hessian(flat_grads,params):
    full_hessian = []
    for i in range(flat_grads.size()[0]):
        temp_hess = torch.autograd.grad(flat_grads[i], params, retain_graph=True)
        full_hessian.append(ttv(temp_hess))
    return torch.stack(full_hessian)

def run_psps2(train_data, train_target, train_dataloader, epochs, precond_method="cg", **kwargs):

    torch.manual_seed(0)
    np.random.seed(0)
    # parameters
    w = torch.zeros(train_data.shape[1], device=device).requires_grad_()

    # save loss and grad size to history
    hist = []

    optimizer = torch.optim.SGD([w],lr=1)
    loss = loss_function(w, train_data.to(device), train_target.to(device))

    # print("loss",loss)

    g, = torch.autograd.grad(loss, w, create_graph=True)
    hessian = flat_hessian(g,[w])
    f_grad = g.clone().detach()


    # print("grad",torch.norm(g).item())

    if precond_method == "none":
        D = torch.ones_like(w)
    elif precond_method == "hutch":
        alpha=0.1
        beta=0.999
        init_iters = kwargs["hutch_init_iters"]
        Dk = diag_estimate_old(w, g, init_iters)
    elif precond_method == "cg" or precond_method == "pcg":
        s = torch.zeros_like(w) # s = H_inv * grad
        r = f_grad - torch.autograd.grad(g, w, grad_outputs=s, retain_graph=True)[0]
        p = r.detach().clone()
        r_prev = torch.dot(r, r)
        MAX_ITER = train_data.shape[1] * 2
        # MAX_ITER = 1000

    elif precond_method == "scaling_vec":
        scaling_vec = kwargs["scaling_vec"]
        D = (1 / scaling_vec)**2
    elif precond_method == "adam" or precond_method == "adam_m":
        D = torch.zeros_like(g)
        v = torch.zeros_like(g)
        step_t = torch.tensor(0.)
        betas = (0.9, 0.999)
    elif precond_method == "adagrad" or precond_method == "adagrad_m":
        D = torch.zeros_like(g)
        v = torch.zeros_like(g)

    pcg_method = kwargs.get("pcg_method")
    if pcg_method == "hutch":
        alpha=0.1
        beta=0.999
        init_iters = kwargs["hutch_init_iters"]
        Dk_pcg = diag_estimate_old(w, g, init_iters)
    elif pcg_method == "adam":
        D_pcg = torch.zeros_like(g)
        v_pcg = torch.zeros_like(g)
        step_t_pcg = torch.tensor(0.)
        betas = (0.9, 0.999)
    elif pcg_method == "adagrad":
        D_pcg = torch.zeros_like(g)
        v_pcg = torch.zeros_like(g)
        # v_pcg = torch.diag(hessian)
    elif pcg_method == None:
        D_pcg = torch.ones_like(g)

    cg_steps = []

    for epoch in range(epochs):

        loss = loss_function(w, train_data.to(device), train_target.to(device))
        g, = torch.autograd.grad(loss, w, create_graph=True)
        grad_norm_sq = torch.linalg.norm(g) ** 2
        acc = (np.sign(train_data @ w.detach().numpy()) == train_target).sum() / train_target.shape[0]

        print(f"[{epoch}/{epochs}] | Loss: {loss.item()} | GradNorm^2: {grad_norm_sq.item()} | Accuracy: {acc}")
        hist.append([loss.item(), grad_norm_sq.item(), acc])

        for i, (batch_data, batch_target) in enumerate(train_dataloader):

            loss = loss_function(w, batch_data, batch_target)
            g, = torch.autograd.grad(loss, w, create_graph=True)
            f_grad = g.detach().clone()

            elif precond_method == "pcg":
                
                if pcg_method == "hess_diag":
                #hess = loss_hessian(w, batch_data, batch_target)
                    D_pcg = 1 / torch.diag(hessian)  
                elif pcg_method == "hutch":
                    vk_pcg = diag_estimate_old(w, g, 1)
                    # Smoothing and Truncation
                    Dk_pcg = beta * Dk_pcg + (1 - beta) * vk_pcg
                    Dk_hat = torch.abs(Dk_pcg)
                    Dk_hat[Dk_hat < alpha] = alpha
                    D_pcg = 1 / Dk_hat
                elif pcg_method == "adam":
                    step_t_pcg += 1
                    v_pcg = betas[1] * v_pcg + (1 - betas[1]) * f_grad.square()
                    v_hat = v_pcg / (1 - torch.pow(betas[1], step_t_pcg))
                    D_pcg = 1 / v_hat
                    #D_pcg = 1 / (torch.sqrt(v_hat) + 1e-8)
                elif pcg_method == "adagrad":
                    v_pcg.add_(f_grad.square())
                    #print(v_pcg)
                    # D_pcg = 1/v_pcg
                    # print(torch.norm(v_pcg),"v_pcg")
                    D_pcg = v_pcg
                    eps = 1e-3

                    D_pcg[torch.abs(v_pcg) > eps] = 1 / (v_pcg[torch.abs(v_pcg) > eps])# + 1e-8)

                    # print(torch.norm(D_pcg),"D_pcg")


                    #print(D_pcg)
                elif pcg_method == "none":
                    D_pcg = torch.ones_like(f_grad)

                #hess = loss_hessian(w, batch_data, batch_target)
                
        
                #hess_diag_inv = 1 / torch.diag(hess)

                hess_diag_inv = D_pcg.clone()


                # hess_diag_inv *= 0
                # hess_diag_inv +=1

                # hess_diag=1/hess_diag_inv
                gamma=0.7
            

                # Preconditioned CG is here
                s = torch.zeros_like(w) # s = H_inv * grad
                x = torch.zeros_like(w)
                r = f_grad.clone()
                z = hess_diag_inv * r
                p = z.clone()
                # step_size = 1.0

                for cg_step in range(MAX_ITER):
                    hvp = torch.autograd.grad(g, w, grad_outputs=p, retain_graph=True)[0]
                
                    if torch.dot(p,hvp)<=0:
                        # if cg_step==0:
                            
                        # print("NEGATIVE CURVATURE")
                        s=gamma*x  +(1-gamma)*p*torch.sign(torch.dot(p,f_grad))
                        hvs = torch.autograd.grad(g, w, grad_outputs=s, retain_graph=True)[0]
                        # print("step_size=",torch.dot(s,hvs))
                        # print(torch.max(torch.tensor([loss/torch.dot(s,hvs),0])))
                        # step_size=torch.min(torch.max(torch.tensor([loss/torch.dot(s,hvs),0])),torch.tensor(20))
                        step_size=torch.min(torch.tensor([torch.abs(loss/torch.dot(s,hvs)),5]))
                        #step_size=1.0
                        # print(step_size)
                        # print("Nega:stepsize",step_size)
                        # print(f"PCG Took {cg_step}")
                        break
                    alpha_k = torch.dot(r, z) / torch.dot(p, hvp)
                    # print("alpha",alpha_k)
                    x = x + alpha_k * p
                    # print("x",x*scaling)
                    r_prev = r.clone()
                    r = r - alpha_k * hvp
                    # print(torch.dot(r,hess_diag_inv*r))
                    # if torch.norm(r)<1e-4:
                    # print(torch.dot(r,hess_diag_inv*r),'sssss')
                    if torch.dot(r,hess_diag_inv*r) < 1e-5:
                        s=x
                        # print("hit stopping")
                        # print(f"PCG Took {cg_step}")
                        # Ax = torch.autograd.grad(g, w, grad_outputs=s, retain_graph=True)[0]
                        # diff = torch.norm(Ax - f_grad)
                        # print(f"PCG Took {cg_step} to reach diff={diff}")
                        # cg_steps.append(cg_step)
                        grad_norm_sq_scaled = torch.dot(f_grad, s)
                        if 2 * loss <= grad_norm_sq_scaled:
                            c = loss / ( grad_norm_sq_scaled )
                            det = 1 - 2 * c
                            if det < 0.0:
                                step_size = 1.0 
                            else:
                                # print("**")
                                step_size = 1 - torch.sqrt(det)
                        else:
                            # print(f"[{epoch}, {i}] No solution")
                            # print("***")
                            step_size = 1.0
                        # print("sp:stepsize",step_size)
                        
                        break

                    z_prev = z.clone()
                    z = hess_diag_inv * r
                    beta_k = torch.dot(r, z) / torch.dot(r_prev, z_prev)
                    p = z + beta_k * p



            with torch.no_grad():
                w.sub_(step_size *s)


    return hist

# hist_pcg = run_psps2(train_data, train_target, train_dataloader, EPOCHS, precond_method="pcg",pcg_method="adagrad")

# %%
class SANIA_PCG(BaseOptimizer):
    def __init__(self, params: np.ndarray, 
                 lr: float = 1.0):
        self.params = params
        self.lr = lr 
        
        self.defaults = dict(lr=lr)
        
    def step(self, loss: np.ndarray, grad: np.ndarray, preconditioner: np.ndarray):
        
        s = grad / preconditioner
        
        # Scaled norm of gradients ||g||_{inv(B_t)}
        grad_norm = np.dot(grad, s)

        # Polyak step size
        step_size = 1.0 
        if 2 * loss.item() <= grad_norm:
            c = loss.item() / ( grad_norm )
            det = 1 - 2 * c
            if det > 0.0:
                step_size = 1 - np.sqrt(det)
        
        self.params -= self.lr * step_size * s
        
        return loss, grad
